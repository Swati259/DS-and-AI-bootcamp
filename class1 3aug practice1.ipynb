# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SWATI DEVI\\Desktop\\data analyst'

# %%
os.chdir('C:\\Users\\SWATI DEVI')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SWATI DEVI'

# %%
pwd
# Out:
# 'C:\\Users\\SWATI DEVI'

# %%
os.chdir('C:\\Users\\SWATI DEVI\\Desktop\\data analyst')

# %%
import pandas as pd
pd.read_excel('Power BI Dataset.xlsx')
# Out:
#       Order ID Order Date        Customer Name        City         Country  \
# 0            1 2017-01-01           Ruby Patel   Stockholm          Sweden
# 1            2 2017-01-03       Summer Hayward   Southport  United Kingdom
# 2            3 2017-01-04     Devin Huddleston     Valence          France
# 3            4 2017-01-04          Mary Parker  Birmingham  United Kingdom
# 4            5 2017-01-05         Daniel Burke  Echirolles          France
# ...        ...        ...                  ...         ...             ...
# 4110      4111 2020-12-31         Eloise Sykes   Bielefeld         Germany
# 4111      4112 2020-12-31         Jose Gambino  Maidenhead  United Kingdom
# 4112      4113 2020-12-31          Leon Barnes   Worcester  United Kingdom
# 4113      4114 2020-12-31  Rebecca Chamberlain     Hamburg         Germany
# 4114      4115 2020-12-31      Daniel Hamilton   Eindhoven     Netherlands
#
#                        State   Region      Segment     Ship Mode  \
# ...

# %%
pd.read_excel('C:\\Users\\SWATI DEVI\\Desktop\\data analyst\\Power BI Dataset.xlsx')
# Out:
#       Order ID Order Date        Customer Name        City         Country  \
# 0            1 2017-01-01           Ruby Patel   Stockholm          Sweden
# 1            2 2017-01-03       Summer Hayward   Southport  United Kingdom
# 2            3 2017-01-04     Devin Huddleston     Valence          France
# 3            4 2017-01-04          Mary Parker  Birmingham  United Kingdom
# 4            5 2017-01-05         Daniel Burke  Echirolles          France
# ...        ...        ...                  ...         ...             ...
# 4110      4111 2020-12-31         Eloise Sykes   Bielefeld         Germany
# 4111      4112 2020-12-31         Jose Gambino  Maidenhead  United Kingdom
# 4112      4113 2020-12-31          Leon Barnes   Worcester  United Kingdom
# 4113      4114 2020-12-31  Rebecca Chamberlain     Hamburg         Germany
# 4114      4115 2020-12-31      Daniel Hamilton   Eindhoven     Netherlands
#
#                        State   Region      Segment     Ship Mode  \
# ...
